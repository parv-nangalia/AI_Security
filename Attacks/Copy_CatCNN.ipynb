# %%
# !pip install adversarial-robustness-toolbox
# Out:
# Requirement already satisfied: adversarial-robustness-toolbox in /usr/local/lib/python3.10/dist-packages (1.16.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from adversarial-robustness-toolbox) (1.23.5)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from adversarial-robustness-toolbox) (1.11.3)
# Requirement already satisfied: scikit-learn<1.2.0,>=0.22.2 in /usr/local/lib/python3.10/dist-packages (from adversarial-robustness-toolbox) (1.1.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from adversarial-robustness-toolbox) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from adversarial-robustness-toolbox) (67.7.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from adversarial-robustness-toolbox) (4.66.1)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.2.0,>=0.22.2->adversarial-robustness-toolbox) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.2.0,>=0.22.2->adversarial-robustness-toolbox) (3.2.0)

# %%
import art
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Flatten, InputLayer, Reshape

from art.estimators.classification import KerasClassifier

tf.compat.v1.disable_eager_execution()
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.debugging.set_log_device_placement(True)
# Out:
# Num GPUs Available:  0

# %%
import art
from art.utils import load_mnist

# Load the dataset, and split the test data into test and steal datasets.
(x_train, y_train), (x_test0, y_test0), _, _ = load_mnist()
len_steal = 5000
indices = np.random.permutation(len(x_test0))
x_steal = x_test0[indices[:len_steal]]
y_steal = y_test0[indices[:len_steal]]
x_test = x_test0[indices[len_steal:]]
y_test = y_test0[indices[len_steal:]]

im_shape = x_train[0].shape
def get_model(num_classes=10, c1=32, c2=64, d1=128):
    model = Sequential()
    model.add(Conv2D(c1, kernel_size=(3, 3), activation='relu', input_shape=im_shape))
    model.add(Conv2D(c2, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(d1, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss=keras.losses.categorical_crossentropy, optimizer="sgd",
                          metrics=['accuracy'])
    return model

# %%
num_epochs = 5
model = get_model(num_classes=10, c1=32, c2=64, d1=128)
print("Original model training:")
model.fit(x_train, y_train, batch_size=100, epochs=num_epochs)
print("Original model evaluation:")
print(model.evaluate(x_test, y_test))
classifier_original = KerasClassifier(model, clip_values=(0, 1), use_logits=False)
# Out:
# Original model training:
# Train on 60000 samples
# Device mapping: no known devices.
# Epoch 1/5
# 60000/60000 [==============================] - 83s 1ms/sample - loss: 0.6768 - accuracy: 0.8181
# Epoch 2/5
# 60000/60000 [==============================] - 79s 1ms/sample - loss: 0.2545 - accuracy: 0.9237
# Epoch 3/5
# 60000/60000 [==============================] - 77s 1ms/sample - loss: 0.1933 - accuracy: 0.9426
# Epoch 4/5
# 60000/60000 [==============================] - 79s 1ms/sample - loss: 0.1599 - accuracy: 0.9520
# Epoch 5/5
# 60000/60000 [==============================] - 85s 1ms/sample - loss: 0.1372 - accuracy: 0.9585
# Original model evaluation:
# c:\Users\parv.nangalia\Desktop\AIHackathon\env\Lib\site-packages\keras\src\engine\training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# [0.13675097302496433, 0.959]

# %%
# Stealing from the unprotected classifier.
from art.attacks import ExtractionAttack
from art.attacks.extraction import CopycatCNN, KnockoffNets, FunctionallyEquivalentExtraction

attack_catalogue = {"Probabilistic CopycatCNN": CopycatCNN(classifier=classifier_original,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=True),
                    "Argmax CopycatCNN": CopycatCNN(classifier=classifier_original,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=False),
                    "Probabilistic KnockoffNets": KnockoffNets(classifier=classifier_original,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=True),
                    "Argmax KnockoffNets": KnockoffNets(classifier=classifier_original,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=False),
                   }

results = []
for len_steal in [250, 500, 1000, 2000, 4000, 5000]:
    indices = np.random.permutation(len(x_test0))
    x_steal = x_test0[indices[:len_steal]]
    y_steal = y_test0[indices[:len_steal]]
    x_test = x_test0[indices[len_steal:]]
    y_test = y_test0[indices[len_steal:]]

    for name, attack in attack_catalogue.items():
        model_stolen = get_model(num_classes=10, c1=32, c2=64, d1=128)
        classifier_stolen = KerasClassifier(model_stolen, clip_values=(0, 1), use_logits=False)
        classifier_stolen = attack.extract(x_steal, y_steal, thieved_classifier=classifier_stolen)
        acc = classifier_stolen._model.evaluate(x_test, y_test)[1]
        print(name, ":", acc)
        results.append((name, len_steal, acc))
# Out:
# c:\Users\parv.nangalia\Desktop\AIHackathon\env\Lib\site-packages\keras\src\engine\training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Train on 250 samples
# Epoch 1/5
# 250/250 [==============================] - 1s 2ms/sample - loss: 2.2803 - accuracy: 0.1640
# Epoch 2/5
# 250/250 [==============================] - 0s 2ms/sample - loss: 2.2563 - accuracy: 0.2320
# Epoch 3/5
# 250/250 [==============================] - 0s 2ms/sample - loss: 2.2314 - accuracy: 0.3080
# Epoch 4/5
# 250/250 [==============================] - 1s 2ms/sample - loss: 2.2071 - accuracy: 0.3400
# Epoch 5/5
# 250/250 [==============================] - 1s 2ms/sample - loss: 2.1801 - accuracy: 0.3840
# Probabilistic CopycatCNN : 0.2628718
# Train on 250 samples
# Epoch 1/5
# 250/250 [==============================] - 0s 2ms/sample - loss: 2.3034 - accuracy: 0.0880
# Epoch 2/5
# 250/250 [==============================] - 0s 2ms/sample - loss: 2.2800 - accuracy: 0.1760
# Epoch 3/5
# 250/250 [==============================] - 0s 2ms/sample - loss: 2.2583 - accuracy: 0.2720
# Epoch 4/5
# 250/250 [==============================] - 0s 2ms/sample - loss: 2.2388 - accuracy: 0.3480
# Epoch 5/5
# 250/250 [==============================] - 0s 2ms/sample - loss: 2.2185 - accuracy: 0.3200
# Argmax CopycatCNN : 0.24728206
# Probabilistic KnockoffNets : 0.16728204
# Argmax KnockoffNets : 0.23723076
# Train on 500 samples
# Epoch 1/5
# 500/500 [==============================] - 1s 2ms/sample - loss: 2.3014 - accuracy: 0.0800
# Epoch 2/5
# 500/500 [==============================] - 1s 2ms/sample - loss: 2.2764 - accuracy: 0.1400
# Epoch 3/5
# 500/500 [==============================] - 1s 2ms/sample - loss: 2.2509 - accuracy: 0.2540
# Epoch 4/5
# 500/500 [==============================] - 1s 2ms/sample - loss: 2.2217 - accuracy: 0.2720
# Epoch 5/5
# 500/500 [==============================] - 1s 2ms/sample - loss: 2.1864 - accuracy: 0.3000
# Probabilistic CopycatCNN : 0.27557895
# Train on 500 samples
# Epoch 1/5
# 500/500 [==============================] - 1s 2ms/sample - loss: 2.2927 - accuracy: 0.1920
# Epoch 2/5
# 500/500 [==============================] - 1s 2ms/sample - loss: 2.2667 - accuracy: 0.3420
# Epoch 3/5
# 500/500 [==============================] - 1s 2ms/sample - loss: 2.2400 - accuracy: 0.3680
# Epoch 4/5
# 500/500 [==============================] - 1s 2ms/sample - loss: 2.2102 - accuracy: 0.3700
# Epoch 5/5
# 500/500 [==============================] - 1s 2ms/sample - loss: 2.1731 - accuracy: 0.4020
# Argmax CopycatCNN : 0.38978946
# Probabilistic KnockoffNets : 0.39673683
# Argmax KnockoffNets : 0.5686316
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 2s 2ms/sample - loss: 2.2789 - accuracy: 0.1530
# Epoch 2/5
# 1000/1000 [==============================] - 2s 2ms/sample - loss: 2.2373 - accuracy: 0.1730
# Epoch 3/5
# 1000/1000 [==============================] - 2s 2ms/sample - loss: 2.1798 - accuracy: 0.2180
# Epoch 4/5
# 1000/1000 [==============================] - 2s 2ms/sample - loss: 2.0846 - accuracy: 0.3870
# Epoch 5/5
# 1000/1000 [==============================] - 2s 2ms/sample - loss: 1.9085 - accuracy: 0.5230
# Probabilistic CopycatCNN : 0.5642222
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 2.2821 - accuracy: 0.1420
# Epoch 2/5
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 2.2183 - accuracy: 0.3350
# Epoch 3/5
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 2.1232 - accuracy: 0.4840
# Epoch 4/5
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.9524 - accuracy: 0.5870
# Epoch 5/5
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.6458 - accuracy: 0.7100
# Argmax CopycatCNN : 0.74244446
# Probabilistic KnockoffNets : 0.5888889
# Argmax KnockoffNets : 0.69233334
# Train on 2000 samples
# Epoch 1/5
# 2000/2000 [==============================] - 3s 1ms/sample - loss: 2.2347 - accuracy: 0.3155
# Epoch 2/5
# 2000/2000 [==============================] - 3s 2ms/sample - loss: 1.9947 - accuracy: 0.5465
# Epoch 3/5
# 2000/2000 [==============================] - 3s 2ms/sample - loss: 1.3411 - accuracy: 0.7290
# Epoch 4/5
# 2000/2000 [==============================] - 3s 2ms/sample - loss: 0.7236 - accuracy: 0.8305
# Epoch 5/5
# 2000/2000 [==============================] - 3s 1ms/sample - loss: 0.5228 - accuracy: 0.8730
# Probabilistic CopycatCNN : 0.84875
# Train on 2000 samples
# Epoch 1/5
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 2.2450 - accuracy: 0.2750
# Epoch 2/5
# 2000/2000 [==============================] - 3s 1ms/sample - loss: 2.0601 - accuracy: 0.5545
# Epoch 3/5
# 2000/2000 [==============================] - 3s 2ms/sample - loss: 1.4747 - accuracy: 0.7125
# Epoch 4/5
# 2000/2000 [==============================] - 3s 2ms/sample - loss: 0.7495 - accuracy: 0.8290
# Epoch 5/5
# 2000/2000 [==============================] - 3s 2ms/sample - loss: 0.4952 - accuracy: 0.8640
# Argmax CopycatCNN : 0.7965
# Probabilistic KnockoffNets : 0.863625
# Argmax KnockoffNets : 0.816375
# Train on 4000 samples
# Epoch 1/5
# 4000/4000 [==============================] - 6s 1ms/sample - loss: 2.2269 - accuracy: 0.2542
# Epoch 2/5
# 4000/4000 [==============================] - 6s 1ms/sample - loss: 1.5767 - accuracy: 0.6520
# Epoch 3/5
# 4000/4000 [==============================] - 6s 1ms/sample - loss: 0.6098 - accuracy: 0.8485
# Epoch 4/5
# 4000/4000 [==============================] - 6s 1ms/sample - loss: 0.4196 - accuracy: 0.8878
# Epoch 5/5
# 4000/4000 [==============================] - 5s 1ms/sample - loss: 0.3723 - accuracy: 0.8978
# Probabilistic CopycatCNN : 0.87616664
# Train on 4000 samples
# Epoch 1/5
# 4000/4000 [==============================] - 6s 2ms/sample - loss: 2.1535 - accuracy: 0.4378
# Epoch 2/5
# 4000/4000 [==============================] - 7s 2ms/sample - loss: 1.0978 - accuracy: 0.7960
# Epoch 3/5
# 4000/4000 [==============================] - 7s 2ms/sample - loss: 0.4516 - accuracy: 0.8658
# Epoch 4/5
# 4000/4000 [==============================] - 7s 2ms/sample - loss: 0.3398 - accuracy: 0.8957
# Epoch 5/5
# 4000/4000 [==============================] - 6s 1ms/sample - loss: 0.2786 - accuracy: 0.9087
# Argmax CopycatCNN : 0.8653333
# Probabilistic KnockoffNets : 0.89933336
# Argmax KnockoffNets : 0.8685
# Train on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 8s 2ms/sample - loss: 2.1347 - accuracy: 0.3994
# Epoch 2/5
# 5000/5000 [==============================] - 8s 2ms/sample - loss: 0.9445 - accuracy: 0.8058
# Epoch 3/5
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 0.4350 - accuracy: 0.8904
# Epoch 4/5
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 0.3681 - accuracy: 0.9022
# Epoch 5/5
# 5000/5000 [==============================] - 9s 2ms/sample - loss: 0.3249 - accuracy: 0.9218
# Probabilistic CopycatCNN : 0.8628
# Train on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 8s 2ms/sample - loss: 2.0691 - accuracy: 0.3832
# Epoch 2/5
# 5000/5000 [==============================] - 8s 2ms/sample - loss: 0.7755 - accuracy: 0.8290
# Epoch 3/5
# 5000/5000 [==============================] - 7s 1ms/sample - loss: 0.3762 - accuracy: 0.8908
# Epoch 4/5
# 5000/5000 [==============================] - 7s 1ms/sample - loss: 0.3270 - accuracy: 0.8998
# Epoch 5/5
# 5000/5000 [==============================] - 7s 1ms/sample - loss: 0.2565 - accuracy: 0.9196
# Argmax CopycatCNN : 0.7782
# Probabilistic KnockoffNets : 0.7876
# Argmax KnockoffNets : 0.8282

# %%
import pandas as pd
df = pd.DataFrame(results, columns=('Method Name', 'Stealing Dataset Size', 'Accuracy'))
fig, ax = plt.subplots(figsize=(8,6))
ax.set_xlabel("Stealing Dataset Size")
ax.set_ylabel("Stolen Model Accuracy")
for name, group in df.groupby("Method Name"):
    group.plot(1, 2, ax=ax, label=name)
plt.show()

# %%
# Prepare the defense layer.
from art.defences.postprocessor import ReverseSigmoid
postprocessor = ReverseSigmoid(beta=1.0, gamma=0.2)
classifier_protected = KerasClassifier(model, clip_values=(0, 1), use_logits=False, postprocessing_defences=postprocessor)

# Below is used by `FunctionallyEquivalentExtraction`.
model_flat = Sequential([InputLayer([784]), Reshape([28, 28, 1]), model])
model_flat.compile('sgd', 'categorical_crossentropy', ['accuracy'])
classifier_flat_protected = KerasClassifier(model_flat, clip_values=(0, 1), use_logits=False, postprocessing_defences=postprocessor)

# %%
# Stealing from the protected classifier.

attack_catalogue = {
                    "Probabilistic CopycatCNN (vs. Protected)": CopycatCNN(classifier=classifier_protected,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=True),
                    "Argmax CopycatCNN (vs. Protected)": CopycatCNN(classifier=classifier_protected,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=False),
                    "Probabilistic KnockoffNets (vs. Protected)": KnockoffNets(classifier=classifier_protected,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=True),
                    "Argmax KnockoffNets (vs. Protected)": KnockoffNets(classifier=classifier_protected,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=False),
                     # "FunctionallyEquivalentExtraction": FunctionallyEquivalentExtraction(classifier=classifier_flat_protected,
                     #                           num_neurons=128),  # This one takes too long time for this dataset/model.
                    }

results_protected = []
for len_steal in [250, 500, 1000, 2000, 4000, 5000]:
    indices = np.random.permutation(len(x_test0))
    x_steal = x_test0[indices[:len_steal]]
    y_steal = y_test0[indices[:len_steal]]
    x_test = x_test0[indices[len_steal:]]
    y_test = y_test0[indices[len_steal:]]

    for name, attack in attack_catalogue.items():
        model_stolen = get_model(num_classes=10, c1=32, c2=64, d1=128)
        classifier_stolen = KerasClassifier(model_stolen, clip_values=(0, 1), use_logits=False)
        if name=="FunctionallyEquivalentExtraction":
            classifier_stolen = attack.extract(np.reshape(x_steal, [len(x_steal), -1]), y_steal, thieved_classifier=classifier_stolen)
        else:
            classifier_stolen = attack.extract(x_steal, y_steal, thieved_classifier=classifier_stolen)

        acc = classifier_stolen._model.evaluate(x_test, y_test)[1]
        print(name, ":", acc)
        results_protected.append((name, len_steal, acc))
# Out:
# Train on 250 samples
# Epoch 1/5
# 250/250 [==============================] - 0s 2ms/sample - loss: 2.3048 - accuracy: 0.1200
# Epoch 2/5
# 250/250 [==============================] - 0s 1ms/sample - loss: 2.3040 - accuracy: 0.1080
# Epoch 3/5
# 250/250 [==============================] - 0s 1ms/sample - loss: 2.3033 - accuracy: 0.1080
# Epoch 4/5
# 250/250 [==============================] - 0s 2ms/sample - loss: 2.3028 - accuracy: 0.1040
# Epoch 5/5
# 250/250 [==============================] - 0s 2ms/sample - loss: 2.3024 - accuracy: 0.1080
# c:\Users\parv.nangalia\Desktop\AIHackathon\env\Lib\site-packages\keras\src\engine\training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# Probabilistic CopycatCNN (vs. Protected) : 0.11384615
# Train on 250 samples
# Epoch 1/5
# 250/250 [==============================] - 0s 2ms/sample - loss: 2.3021 - accuracy: 0.0800
# Epoch 2/5
# 250/250 [==============================] - 0s 1ms/sample - loss: 2.2843 - accuracy: 0.1400
# Epoch 3/5
# 250/250 [==============================] - 0s 1ms/sample - loss: 2.2671 - accuracy: 0.1760
# Epoch 4/5
# 250/250 [==============================] - 0s 1ms/sample - loss: 2.2487 - accuracy: 0.2520
# Epoch 5/5
# 250/250 [==============================] - 0s 1ms/sample - loss: 2.2299 - accuracy: 0.2960
# Argmax CopycatCNN (vs. Protected) : 0.29179487
# Probabilistic KnockoffNets (vs. Protected) : 0.105333336
# Argmax KnockoffNets (vs. Protected) : 0.2871795
# Train on 500 samples
# Epoch 1/5
# 500/500 [==============================] - 1s 2ms/sample - loss: 2.3038 - accuracy: 0.1080
# Epoch 2/5
# 500/500 [==============================] - 1s 1ms/sample - loss: 2.3033 - accuracy: 0.1100
# Epoch 3/5
# 500/500 [==============================] - 1s 1ms/sample - loss: 2.3029 - accuracy: 0.1140
# Epoch 4/5
# 500/500 [==============================] - 1s 1ms/sample - loss: 2.3026 - accuracy: 0.1160
# Epoch 5/5
# 500/500 [==============================] - 1s 1ms/sample - loss: 2.3023 - accuracy: 0.1160
# Probabilistic CopycatCNN (vs. Protected) : 0.10063158
# Train on 500 samples
# Epoch 1/5
# 500/500 [==============================] - 1s 2ms/sample - loss: 2.2983 - accuracy: 0.0840
# Epoch 2/5
# 500/500 [==============================] - 1s 1ms/sample - loss: 2.2825 - accuracy: 0.1160
# Epoch 3/5
# 500/500 [==============================] - 1s 1ms/sample - loss: 2.2661 - accuracy: 0.1440
# Epoch 4/5
# 500/500 [==============================] - 1s 1ms/sample - loss: 2.2479 - accuracy: 0.1920
# Epoch 5/5
# 500/500 [==============================] - 1s 1ms/sample - loss: 2.2261 - accuracy: 0.2320
# Argmax CopycatCNN (vs. Protected) : 0.20252632
# Probabilistic KnockoffNets (vs. Protected) : 0.15463158
# Argmax KnockoffNets (vs. Protected) : 0.44031578
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 2s 2ms/sample - loss: 2.3043 - accuracy: 0.1210
# Epoch 2/5
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 2.3030 - accuracy: 0.1300
# Epoch 3/5
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 2.3022 - accuracy: 0.1440
# Epoch 4/5
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 2.3017 - accuracy: 0.1540
# Epoch 5/5
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 2.3013 - accuracy: 0.1450
# Probabilistic CopycatCNN (vs. Protected) : 0.13844444
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 2.2841 - accuracy: 0.2230
# Epoch 2/5
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 2.2481 - accuracy: 0.4030
# Epoch 3/5
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 2.2004 - accuracy: 0.3950
# Epoch 4/5
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 2.1271 - accuracy: 0.4450
# Epoch 5/5
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.9996 - accuracy: 0.4920
# Argmax CopycatCNN (vs. Protected) : 0.58022225
# Probabilistic KnockoffNets (vs. Protected) : 0.101333335
# Argmax KnockoffNets (vs. Protected) : 0.44377777
# Train on 2000 samples
# Epoch 1/5
# 2000/2000 [==============================] - 3s 1ms/sample - loss: 2.3051 - accuracy: 0.0895
# Epoch 2/5
# 2000/2000 [==============================] - 3s 1ms/sample - loss: 2.3033 - accuracy: 0.0965
# Epoch 3/5
# 2000/2000 [==============================] - 3s 1ms/sample - loss: 2.3023 - accuracy: 0.1060
# Epoch 4/5
# 2000/2000 [==============================] - 3s 1ms/sample - loss: 2.3016 - accuracy: 0.1080
# Epoch 5/5
# 2000/2000 [==============================] - 3s 1ms/sample - loss: 2.3012 - accuracy: 0.1150
# Probabilistic CopycatCNN (vs. Protected) : 0.135
# Train on 2000 samples
# Epoch 1/5
# 2000/2000 [==============================] - 4s 2ms/sample - loss: 2.2557 - accuracy: 0.2780
# Epoch 2/5
# 2000/2000 [==============================] - 3s 2ms/sample - loss: 2.0232 - accuracy: 0.5750
# Epoch 3/5
# 2000/2000 [==============================] - 3s 2ms/sample - loss: 1.3379 - accuracy: 0.7445
# Epoch 4/5
# 2000/2000 [==============================] - 3s 2ms/sample - loss: 0.6875 - accuracy: 0.8375
# Epoch 5/5
# 2000/2000 [==============================] - 3s 2ms/sample - loss: 0.4667 - accuracy: 0.8755
# Argmax CopycatCNN (vs. Protected) : 0.820375
# Probabilistic KnockoffNets (vs. Protected) : 0.208875
# Argmax KnockoffNets (vs. Protected) : 0.81775
# Train on 4000 samples
# Epoch 1/5
# 4000/4000 [==============================] - 6s 2ms/sample - loss: 2.3025 - accuracy: 0.1192
# Epoch 2/5
# 4000/4000 [==============================] - 7s 2ms/sample - loss: 2.3008 - accuracy: 0.1303
# Epoch 3/5
# 4000/4000 [==============================] - 7s 2ms/sample - loss: 2.3000 - accuracy: 0.1538
# Epoch 4/5
# 4000/4000 [==============================] - 7s 2ms/sample - loss: 2.2995 - accuracy: 0.1828
# Epoch 5/5
# 4000/4000 [==============================] - 6s 1ms/sample - loss: 2.2991 - accuracy: 0.2115
# Probabilistic CopycatCNN (vs. Protected) : 0.22383334
# Train on 4000 samples
# Epoch 1/5
# 4000/4000 [==============================] - 6s 1ms/sample - loss: 2.0489 - accuracy: 0.4830
# Epoch 2/5
# 4000/4000 [==============================] - 6s 1ms/sample - loss: 0.8319 - accuracy: 0.8077
# Epoch 3/5
# 4000/4000 [==============================] - 6s 1ms/sample - loss: 0.4125 - accuracy: 0.8827
# Epoch 4/5
# 4000/4000 [==============================] - 6s 1ms/sample - loss: 0.3274 - accuracy: 0.9075
# Epoch 5/5
# 4000/4000 [==============================] - 6s 1ms/sample - loss: 0.2871 - accuracy: 0.9162
# Argmax CopycatCNN (vs. Protected) : 0.8566667
# Probabilistic KnockoffNets (vs. Protected) : 0.34033334
# Argmax KnockoffNets (vs. Protected) : 0.89316666
# Train on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 7s 1ms/sample - loss: 2.3028 - accuracy: 0.0530
# Epoch 2/5
# 5000/5000 [==============================] - 7s 1ms/sample - loss: 2.3010 - accuracy: 0.1076
# Epoch 3/5
# 5000/5000 [==============================] - 6s 1ms/sample - loss: 2.3001 - accuracy: 0.1916
# Epoch 4/5
# 5000/5000 [==============================] - 6s 1ms/sample - loss: 2.2994 - accuracy: 0.2478
# Epoch 5/5
# 5000/5000 [==============================] - 7s 1ms/sample - loss: 2.2989 - accuracy: 0.2738
# Probabilistic CopycatCNN (vs. Protected) : 0.2792
# Train on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 7s 1ms/sample - loss: 2.1340 - accuracy: 0.3286
# Epoch 2/5
# 5000/5000 [==============================] - 7s 1ms/sample - loss: 0.9262 - accuracy: 0.7842
# Epoch 3/5
# 5000/5000 [==============================] - 7s 1ms/sample - loss: 0.4049 - accuracy: 0.8796
# Epoch 4/5
# 5000/5000 [==============================] - 7s 1ms/sample - loss: 0.3189 - accuracy: 0.9042
# Epoch 5/5
# 5000/5000 [==============================] - 7s 1ms/sample - loss: 0.2792 - accuracy: 0.9160
# Argmax CopycatCNN (vs. Protected) : 0.8222
# Probabilistic KnockoffNets (vs. Protected) : 0.224
# Argmax KnockoffNets (vs. Protected) : 0.7296

# %%
import pandas as pd
df_protected = pd.DataFrame(results_protected, columns=('Method Name', 'Stealing Dataset Size', 'Accuracy'))
fig, ax = plt.subplots(figsize=(8,6))
ax.set_xlabel("Stealing Dataset Size")
ax.set_ylabel("Stolen Model Accuracy")
for name, group in df_protected.groupby("Method Name"):
    group.plot(1, 2, ax=ax, label=name)
plt.show()

# %%
df_combined = pd.concat([df, df_protected])
groupby = df_combined.groupby("Method Name")

# %%
names = ["CopycatCNN", "KnockoffNets"]
for name in names:
    fig, ax = plt.subplots(figsize=(8,6))
    groupby.get_group("Probabilistic " + name).plot(1,2,ax=ax, label="Probabilistic " + name)
    groupby.get_group("Probabilistic " + name + " (vs. Protected)").plot(1,2,ax=ax, label="Probabilistic " + name + " (vs. Protected)")
    ax.set_xlabel("Stealing Dataset Size")
    ax.set_ylabel("Stolen Model Accuracy")
    fig.show()
# Out:
# C:\Users\parv.nangalia\AppData\Local\Temp\ipykernel_16744\2890188776.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# C:\Users\parv.nangalia\AppData\Local\Temp\ipykernel_16744\2890188776.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
